# %% [markdown]
# This code finds all mislabelled data, lets you hear it and then you can relabel it yourself. The output file is used in embed_wav.ipynb to remove all unwanted files

# %%
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from glob import glob
from cv import RepeatedStratifiedGroupKFold
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, ConfusionMatrixDisplay
import s3fs

from phonemes import get_phoneme_prediction
from embed import embed_from_local, embed_from_s3
import operator
from utils import *

from IPython.display import Audio
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# Embedding model loaded, embedding shape: (None, None, 1, 96)

# %%
# connect to s3
# must first enter AWS creds in cmd/terminal
s3 = s3fs.S3FileSystem()

# %%
consonant_list = ['b','p','k','g','m','n','t','d']  # other consonants excluded b/c of small sample size
NUM_CLASSES = len(consonant_list)  # 8 consonants
CONTEXT_SIZE = NUM_CLASSES * 2  # no of dims to extract from embeddings
RATE = 16_000

# %%
org_df = pd.read_csv('embeddings_org_ravel.txt')  # unaltered data
aug_df = pd.read_csv('embeddings_aug_ravel.txt')  # augmented data

# %%
all_df = pd.concat([org_df, aug_df], ignore_index=True)
all_df.shape
# Out:
# (5535, 1539)

# %%
preds_list = []
nrows = all_df.shape[0]
for idx in range(nrows):
    wav_m = all_df.iloc[idx,:1536].to_numpy()
    wav_m = np.reshape(wav_m,(1, 16,1,96))
    wav_m_tens = tf.convert_to_tensor(wav_m, np.float32)
    ph_pred = get_phoneme_prediction(wav_m_tens)
    # get the consonant with the highest score as a str
    max_con = max(ph_pred.items(), key=operator.itemgetter(1))[0]
    preds_list.append(max_con)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-be5ec549da11> in <module>
#       2 nrows = all_df.shape[0]
#       3 for idx in range(nrows):
# ----> 4     wav_m = all_df.iloc[idx,:1536].to_numpy()
#       5     wav_m = np.reshape(wav_m,(1, 16,1,96))
#       6     wav_m_tens = tf.convert_to_tensor(wav_m, np.float32)
#
# /var/lang/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# /var/lang/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1450         self._has_valid_tuple(tup)
#    1451         with suppress(IndexingError):
# -> 1452             return self._getitem_lowerdim(tup)
#    1453
#    1454         return self._getitem_tuple_same_dim(tup)
#
# /var/lang/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     805                 # We don't need to check for tuples here because those are
#     806                 #  caught by the _is_nested_tuple_indexer check above.
# --> 807                 section = self._getitem_axis(key, axis=i)
#     808
#     809                 # We should never have a scalar section here, because
#
# /var/lang/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1501             self._validate_integer(key, axis)
#    1502
# -> 1503             return self.obj._ixs(key, axis=axis)
#    1504
#    1505     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /var/lang/lib/python3.8/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    2949             # if we are a copy, mark as such
#    2950             copy = isinstance(new_values, np.ndarray) and new_values.base is None
# -> 2951             result = self._constructor_sliced(
#    2952                 new_values,
#    2953                 index=self.columns,
#
# /var/lang/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     367
#     368         generic.NDFrame.__init__(self, data)
# --> 369         self.name = name
#     370         self._set_axis(0, index, fastpath=True)
#     371
#
# /var/lang/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5485             object.__setattr__(self, name, value)
#    5486         elif name in self._metadata:
# -> 5487             object.__setattr__(self, name, value)
#    5488         else:
#    5489             try:
#
# /var/lang/lib/python3.8/site-packages/pandas/core/series.py in name(self, value)
#     538     @name.setter
#     539     def name(self, value: Label) -> None:
# --> 540         validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     541         object.__setattr__(self, "_name", value)
#     542
#
# /var/lang/lib/python3.8/site-packages/pandas/core/dtypes/common.py in validate_all_hashable(error_name, *args)
#    1760     None
#    1761     """
# -> 1762     if not all(is_hashable(arg) for arg in args):
#    1763         if error_name:
#    1764             raise TypeError(f"{error_name} must be a hashable type")
#
# /var/lang/lib/python3.8/site-packages/pandas/core/dtypes/common.py in <genexpr>(.0)
#    1760     None
#    1761     """
# -> 1762     if not all(is_hashable(arg) for arg in args):
#    1763         if error_name:
#    1764             raise TypeError(f"{error_name} must be a hashable type")
#
# /var/lang/lib/python3.8/site-packages/pandas/core/dtypes/inference.py in is_hashable(obj)
#     350     # https://github.com/numpy/numpy/issues/5562
#     351
# --> 352     try:
#     353         hash(obj)
#     354     except TypeError:
#
# KeyboardInterrupt:

# %%
preds_vs_actuals_df = pd.concat([pd.Series(preds_list),all_df['consonants']], axis=1)
preds_vs_actuals_df = preds_vs_actuals_df.iloc[:nrows,:]
mismatches_df = preds_vs_actuals_df[preds_vs_actuals_df[0] != preds_vs_actuals_df['consonants']]

# %%
mislabel_df = pd.DataFrame()
num_mismatches = mismatches_df.shape[0]

for idx, row in mismatches_df.iterrows():
    print(f'File {idx}/{num_mismatches}')
    filepath = org_df['filepath'][idx]
    wav = load_wav(filepath)
    display(Audio(wav, rate=RATE))
    is_correct = input(f"Is this a {row['consonants']} (y/n)?")
    if is_correct == 'n':
        consonant = input('What consonant is this?')
        correction = [[filepath, row['consonants'], consonant]]
        mislabel_df = mislabel_df.append(correction, ignore_index=True)
        
mislabel_df.columns = ['filepath','prev','correction']
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Is this a d (y/n)? y
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Is this a t (y/n)? y
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Is this a t (y/n)? y
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Is this a t (y/n)? y
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Is this a b (y/n)? y
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Is this a b (y/n)? y
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6b801285c72d> in <module>
#       5     wav = load_wav(filepath)
#       6     display(Audio(wav, rate=RATE))
# ----> 7     is_correct = input(f"Is this a {row['consonants']} (y/n)?")
#       8     if is_correct == 'n':
#       9         consonant = input('What consonant is this?')
#
# /var/lang/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
# --> 848         return self._input_request(str(prompt),
#     849             self._parent_ident,
#     850             self._parent_header,
#
# /var/lang/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
mislabel_df.to_csv('mislabelled_data_phase2.txt', index=False)
